# %% [markdown]
# # Instructions
#
# This simulates retail sales for cigarettes, Juul and other e-cigarettes. We are interested in what conclusions you draw from this data about Juul's performance and market impact and how you visualize them.
#
# Feel free to use whatever means you prefer for your analysis and communication of it and its results. What you send back should be able to stand on its own, i.e., we should be able to understand it without requiring additional narration.
#
# Please only use RMA and ignore CRMA and SRMA geographies for this analysis.

# %%
import pandas as pd
import numpy as np
import os 
import sys
import re
import datetime
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'data_exploration.ipynb',
#  'sales.csv',
#  'sku.csv']

# %%
sales = pd.read_csv('sales.csv')
sku = pd.read_csv('sku.csv')

# %%
sales.head(10)
# Out:
#                      Geography     Product                     Time  \
# 0  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 01-31-16
# 1  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 02-28-16
# 2  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 03-27-16
# 3  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 04-24-16
# 4  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 05-22-16
# 5  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 06-19-16
# 6  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 07-17-16
# 7  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 08-14-16
# 8  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 09-11-16
# 9  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 10-09-16
#
#    Dollar Sales   Unit Sales               SKU
# 0   28921840.49  4968512.070  Cigarettes Total
# 1   30276220.80  5139634.753  Cigarettes Total
# 2   31535167.82  5366848.000  Cigarettes Total
# 3   31693487.95  5420033.091  Cigarettes Total
# 4   31390945.73  5380230.139  Cigarettes Total
# 5   31286284.72  5351033.111  Cigarettes Total
# 6   31058485.91  5306152.200  Cigarettes Total
# 7   30747716.96  5259324.210  Cigarettes Total
# 8   30396088.49  5198175.061  Cigarettes Total
# 9   30123052.65  5131669.082  Cigarettes Total

# %%
sku
# Out:
#                                            SKU Legend      Unit Sales  \
# 0                     JUUL-ELECTRONIC SMOKING DEVICES               –
# 1                                          CIGARETTES  75,083,502,411
# 2                          ELECTRONIC SMOKING DEVICES     939,305,632
# 3   JUUL ELCTRNC SMKNG ACSRY MIINT DISPOSABLE 4 CT...      27,211,643
# 4   JUUL ELCTRNC SMKNG ACSRY BRUULE DISPOSABLE 4 C...       7,979,019
# 5   JUUL ELCTRNC SMKNG ACSRY FRUUT DISPOSABLE 4 CT...       7,395,437
# 6   JUUL ELCTRNC SMKNG ACSRY MANGO DISPOSABLE 4 CT...       6,871,591
# 7   JUUL ELCTRNC SMKNG ACSRY TABAAC DISPOSABLE 4 C...       9,532,052
# 8   JUUL ELECTRONIC SMKNG DVC ELECTRONIC CIGRTT KT...       5,596,081
# 9   JUUL ELECTRONIC SMKNG DVC ELECTRONIC CIGRTT KT...       1,533,344
# 10  JUUL ELCTRNC SMKNG ACSRY ASSORTED DISPOSABLE 4...             131
# 11      JUUL ELCTRNC SMKNG ACSRY 1 CT - 0819913011561          35,395
# 12  JUUL ELCTRNC SMKNG ACSRY COOL CUCUMBER DISPOSA...         215,610
# 13  JUUL ELCTRNC SMKNG ACSRY CLASSIC MENTHOL DISPO...          77,402
# 14  JUUL ELCTRNC SMKNG ACSRY CLASSIC TOBACCO DISPO...          33,324
#
#                  SKU
# 0         JUUL Total
# 1   Cigarettes Total
# 2       E-Cigs Total
# 3   JUUL Refill Kits
# 4   JUUL Refill Kits
# 5   JUUL Refill Kits
# 6   JUUL Refill Kits
# 7   JUUL Refill Kits
# 8       JUUL Devices
# 9       JUUL Devices
# 10  JUUL Refill Kits
# 11  JUUL Accessories
# 12  JUUL Refill Kits
# 13  JUUL Refill Kits
# 14  JUUL Refill Kits

# %%
for s in list(sku.iloc[:,0]): print(s)
# Out:
# JUUL-ELECTRONIC SMOKING DEVICES
# CIGARETTES
# ELECTRONIC SMOKING DEVICES
# JUUL ELCTRNC SMKNG ACSRY MIINT DISPOSABLE 4 CT - 0819913011401
# JUUL ELCTRNC SMKNG ACSRY BRUULE DISPOSABLE 4 CT - 0819913011381
# JUUL ELCTRNC SMKNG ACSRY FRUUT DISPOSABLE 4 CT - 0819913011391
# JUUL ELCTRNC SMKNG ACSRY MANGO DISPOSABLE 4 CT - 0819913012441
# JUUL ELCTRNC SMKNG ACSRY TABAAC DISPOSABLE 4 CT - 0819913011421
# JUUL ELECTRONIC SMKNG DVC ELECTRONIC CIGRTT KT RECHARGEABLE 3 CT - 0819913011371
# JUUL ELECTRONIC SMKNG DVC ELECTRONIC CIGRTT KT RECHARGEABLE 2 CT - 0819913011581
# JUUL ELCTRNC SMKNG ACSRY ASSORTED DISPOSABLE 4 CT - 0819913011411
# JUUL ELCTRNC SMKNG ACSRY 1 CT - 0819913011561
# JUUL ELCTRNC SMKNG ACSRY COOL CUCUMBER DISPOSABLE 4 CT - 0819913012471
# JUUL ELCTRNC SMKNG ACSRY CLASSIC MENTHOL DISPOSABLE 4 CT - 0819913012591
# JUUL ELCTRNC SMKNG ACSRY CLASSIC TOBACCO DISPOSABLE 4 CT - 0819913014141

# %%
# filtering sales to only RMA geos
sales_RMA = sales[np.array(sales.Geography.apply(lambda x: re.search("-RMA", x))) != None]
sales_RMA.head(10)
# Out:
#                      Geography     Product                     Time  \
# 0  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 01-31-16
# 1  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 02-28-16
# 2  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 03-27-16
# 3  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 04-24-16
# 4  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 05-22-16
# 5  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 06-19-16
# 6  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 07-17-16
# 7  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 08-14-16
# 8  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 09-11-16
# 9  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 10-09-16
#
#    Dollar Sales   Unit Sales               SKU
# 0   28921840.49  4968512.070  Cigarettes Total
# 1   30276220.80  5139634.753  Cigarettes Total
# 2   31535167.82  5366848.000  Cigarettes Total
# 3   31693487.95  5420033.091  Cigarettes Total
# 4   31390945.73  5380230.139  Cigarettes Total
# 5   31286284.72  5351033.111  Cigarettes Total
# 6   31058485.91  5306152.200  Cigarettes Total
# 7   30747716.96  5259324.210  Cigarettes Total
# 8   30396088.49  5198175.061  Cigarettes Total
# 9   30123052.65  5131669.082  Cigarettes Total

# %%
# Fixing Time column
# is it always ending in 4 weeks?
print(sales_RMA.shape == 
      sales_RMA[np.array(sales_RMA.Time.apply(lambda x: re.search("4 Weeks Ending", x))) != None].shape) #yes

sales_RMA['end_time'] = sales_RMA.Time.apply(lambda t: re.split(" ", t)[-1])
sales_RMA.end_time = sales_RMA.end_time.apply(lambda x: datetime.datetime.strptime(x, "%m-%d-%y"))
sales_RMA['start_time'] = sales_RMA.end_time.apply(lambda x: x - datetime.timedelta(weeks = 4))
# Out:
# True
# /Users/Nicholas_Lechner/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Nicholas_Lechner/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /Users/Nicholas_Lechner/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sales_RMA.head()
# Out:
#                      Geography     Product                     Time  \
# 0  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 01-31-16
# 1  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 02-28-16
# 2  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 03-27-16
# 3  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 04-24-16
# 4  Circle K Florida-RMA - Conv  CIGARETTES  4 Weeks Ending 05-22-16
#
#    Dollar Sales   Unit Sales               SKU   end_time start_time
# 0   28921840.49  4968512.070  Cigarettes Total 2016-01-31 2016-01-03
# 1   30276220.80  5139634.753  Cigarettes Total 2016-02-28 2016-01-31
# 2   31535167.82  5366848.000  Cigarettes Total 2016-03-27 2016-02-28
# 3   31693487.95  5420033.091  Cigarettes Total 2016-04-24 2016-03-27
# 4   31390945.73  5380230.139  Cigarettes Total 2016-05-22 2016-04-24

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
sku['sku_id'] = sku.index
sku['unit_sales'] = sku.loc[:,['Unit Sales']]
sku['sku_legend'] = sku.loc[:,['SKU Legend']]
sku = sku.drop(labels = ['SKU Legend', 'Unit Sales'], axis = 1)
sku
# Out:
#                  SKU  sku_id      unit_sales  \
# 0         JUUL Total       0               –
# 1   Cigarettes Total       1  75,083,502,411
# 2       E-Cigs Total       2     939,305,632
# 3   JUUL Refill Kits       3      27,211,643
# 4   JUUL Refill Kits       4       7,979,019
# 5   JUUL Refill Kits       5       7,395,437
# 6   JUUL Refill Kits       6       6,871,591
# 7   JUUL Refill Kits       7       9,532,052
# 8       JUUL Devices       8       5,596,081
# 9       JUUL Devices       9       1,533,344
# 10  JUUL Refill Kits      10             131
# 11  JUUL Accessories      11          35,395
# 12  JUUL Refill Kits      12         215,610
# 13  JUUL Refill Kits      13          77,402
# 14  JUUL Refill Kits      14          33,324
#
#                                            sku_legend
# 0                     JUUL-ELECTRONIC SMOKING DEVICES
# 1                                          CIGARETTES
# 2                          ELECTRONIC SMOKING DEVICES
# 3   JUUL ELCTRNC SMKNG ACSRY MIINT DISPOSABLE 4 CT...
# 4   JUUL ELCTRNC SMKNG ACSRY BRUULE DISPOSABLE 4 C...
# 5   JUUL ELCTRNC SMKNG ACSRY FRUUT DISPOSABLE 4 CT...
# 6   JUUL ELCTRNC SMKNG ACSRY MANGO DISPOSABLE 4 CT...
# 7   JUUL ELCTRNC SMKNG ACSRY TABAAC DISPOSABLE 4 C...
# 8   JUUL ELECTRONIC SMKNG DVC ELECTRONIC CIGRTT KT...
# 9   JUUL ELECTRONIC SMKNG DVC ELECTRONIC CIGRTT KT...
# 10  JUUL ELCTRNC SMKNG ACSRY ASSORTED DISPOSABLE 4...
# 11      JUUL ELCTRNC SMKNG ACSRY 1 CT - 0819913011561
# 12  JUUL ELCTRNC SMKNG ACSRY COOL CUCUMBER DISPOSA...
# 13  JUUL ELCTRNC SMKNG ACSRY CLASSIC MENTHOL DISPO...
# 14  JUUL ELCTRNC SMKNG ACSRY CLASSIC TOBACCO DISPO...

# %%
sku['sku_legend_text'] = sku.sku_legend.apply(lambda x: ''.join(re.findall("[A-Za-z|\s]", x)).lower())

# %%
# Simplifying SKU Names using TF-IDF
vectorizer = TfidfVectorizer()
response = vectorizer.fit_transform(list(sku.sku_legend_text))
sku_dtm = pd.DataFrame(response.toarray().transpose(), index = vectorizer.get_feature_names())

# %%
sku_simple = []
for word in sku_dtm.index:
    sku_simple.append((sku.sku_legend_text[sku_dtm.loc[word].argmax()], word))
sku_simple

# %%
sku_simple = []
for sku_id in list(sku.sku_id):
    tf = sku_dtm.iloc[:,sku_id]
    tf = sku_dtm.iloc[:,sku_id]
    tf = tf[tf != 0]
    sku_simple.append([sku_id, ' '.join(list(tf.sort_values()[-3:].index))])

# %%
pd.DataFrame(sku_simple)
# Out:
#      0                               1
# 0    0  devices smoking juulelectronic
# 1    1                      cigarettes
# 2    2      electronic devices smoking
# 3    3        elctrnc disposable miint
# 4    4       elctrnc disposable bruule
# 5    5        elctrnc disposable fruut
# 6    6        elctrnc disposable mango
# 7    7       elctrnc disposable tabaac
# 8    8      kt rechargeable electronic
# 9    9      kt rechargeable electronic
# 10  10     elctrnc disposable assorted
# 11  11             smkng acsry elctrnc
# 12  12        disposable cool cucumber
# 13  13      disposable classic menthol
# 14  14      disposable classic tobacco
